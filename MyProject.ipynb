# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:\BIA Projects\BIA-main\BIA Project & Practise\Project & Data\Titanic\Titanic Data.csv')

# %%
df.shape
# Out:
# (891, 12)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.columns.values
# Out:
# array(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.drop(columns = ['Cabin'], inplace = True)

# %%
df['Age'].fillna(df['Age'].mean(), inplace=True)

# %%
df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df['Embarked'].fillna('S', inplace = True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df['SibSp'].value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
df['Parch'].value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %%
df['Survived']=df['Survived'].astype('category')
df['Pclass']=df['Pclass'].astype('category')
df['Sex']=df['Sex'].astype('category')
df['Embarked']=df['Embarked'].astype('category')
df['Age']=df['Age'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    category
#  2   Pclass       891 non-null    category
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    category
#  5   Age          891 non-null    int32
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    category
# dtypes: category(4), float64(1), int32(1), int64(3), object(2)
# memory usage: 49.4+ KB

# %%
df.describe()
# Out:
#        PassengerId         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000   29.544332    0.523008    0.381594   32.204208
# std     257.353842   13.013778    1.102743    0.806057   49.693429
# min       1.000000    0.000000    0.000000    0.000000    0.000000
# 25%     223.500000   22.000000    0.000000    0.000000    7.910400
# 50%     446.000000   29.000000    0.000000    0.000000   14.454200
# 75%     668.500000   35.000000    1.000000    0.000000   31.000000
# max     891.000000   80.000000    8.000000    6.000000  512.329200

# %%
sns.countplot(x="Survived", data=df)
plt.xlabel("Survived")
plt.ylabel("Count")
death_percent = round((df['Survived'].value_counts().values[0]/891)*100)
print('Out of 891 {}% people died in the accident'.format(death_percent))
# Out:
# Out of 891 62% people died in the accident

# %%
print((df['Pclass'].value_counts()/891)*100)
sns.countplot(x='Pclass', data=df)
plt.xlabel('Pclass')
plt.ylabel('Count')
# Out:
# 3    55.106622
# 1    24.242424
# 2    20.650954
# Name: Pclass, dtype: float64
# Text(0, 0.5, 'Count')

# %% [markdown]
# Pclass 3 was the most crowded class with almost 55% of people as compared to other 2 classes.

# %%
print((df['Sex'].value_counts()/891)*100)
sns.countplot(x='Sex', data=df)
# Out:
# male      64.758698
# female    35.241302
# Name: Sex, dtype: float64
# <Axes: xlabel='Sex', ylabel='count'>

# %% [markdown]
# Male passengers were more than female passengers.

# %%
print(df['SibSp'].value_counts())
sns.countplot(x='SibSp', data=df)
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64
# <Axes: xlabel='SibSp', ylabel='count'>

# %% [markdown]
# There are more of single passengers travelling than that of with family.

# %%
print((df['Parch'].value_counts()/891)*100)
sns.countplot(x='Parch', data=df)
# Out:
# 0    76.094276
# 1    13.243547
# 2     8.978676
# 5     0.561167
# 3     0.561167
# 4     0.448934
# 6     0.112233
# Name: Parch, dtype: float64
# <Axes: xlabel='Parch', ylabel='count'>

# %% [markdown]
# Here 76% of the people were travelling alone 13% of people were travelling with someone else.

# %%
print((df['Embarked'].value_counts()/891)*100)
sns.countplot(x='Embarked', data=df)
# Out:
# S    72.502806
# C    18.855219
# Q     8.641975
# Name: Embarked, dtype: float64
# <Axes: xlabel='Embarked', ylabel='count'>

# %% [markdown]
# So moslty 73% of people from titanic were going to Southampton, 19% of people were going to Cherbourg and 9% of people were travelling to Queenstown.

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(6, 5))
sns.histplot(df['Age'], bins=30, kde=True, color='skyblue')

plt.xlabel("Age")
plt.ylabel("Frequency")

plt.show()

print(df['Age'].skew())
print(df['Age'].kurt())
# Out:
# 0.45956263424701577
# 0.9865867453652877

# %% [markdown]
# Maximum people's age were in 25-35.

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: >

# %%
#Just for Information

print("People with age in between 60 & 70 are", df[(df['Age']>60) & (df['Age']<70)].shape[0])
print("People with age greater than 70 & 75 are", df[(df['Age']>=70) & (df['Age']<=75)].shape[0])
print("People with age greater than 75 are", df[df['Age']>75].shape[0])
print("People with age between 0 and 1 are", df[df['Age']<1].shape[0])
# Out:
# People with age in between 60 & 70 are 15
# People with age greater than 70 & 75 are 6
# People with age greater than 75 are 1
# People with age between 0 and 1 are 7

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(5, 5))
sns.histplot(df['Fare'], bins=30, kde=True, color='skyblue')

plt.xlabel("Fare")
plt.ylabel("Frequency")

plt.show()

print(df['Fare'].skew())
print(df['Fare'].kurt())
# Out:
# 4.787316519674893
# 33.39814088089868

# %% [markdown]
# Here we can see people who have buyed tickets in lower price are high.

# %%
sns.boxplot(df['Fare'])

print("People with fare lower than $200 are", df[(df['Fare']<=200)].shape[0])
print("People with fare in between $200 & $300 are", df[(df['Fare']>200) & (df['Fare']<300)].shape[0])
print("People with fare greater than $300 are", df[df['Fare']>300].shape[0])
# Out:
# People with fare lower than $200 are 871
# People with fare in between $200 & $300 are 17
# People with fare greater than $300 are 3

# %%
#Survival with Pclass

sns.countplot(x='Survived', data=df, hue='Pclass')
pd.crosstab(df['Pclass'], df['Survived']).apply(lambda r: round((r/r.sum())*100,1), axis=1)
# Out:
# Survived     0     1
# Pclass
# 1         37.0  63.0
# 2         52.7  47.3
# 3         75.8  24.2

# %%
#Survival with Sex

sns.countplot(x='Survived', data = df, hue='Sex')
pd.crosstab(df['Sex'], df['Survived']).apply(lambda r: round((r/r.sum())*100,1), axis=1)
# Out:
# Survived     0     1
# Sex
# female    25.8  74.2
# male      81.1  18.9

# %%
#Survival with Embarked

sns.countplot(x='Survived', data = df, hue='Embarked')
pd.crosstab(df['Embarked'], df['Survived']).apply(lambda r: round((r/r.sum())*100,1), axis=1)
# Out:
# Survived     0     1
# Embarked
# C         44.6  55.4
# Q         61.0  39.0
# S         66.1  33.9

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.displot(df, x='Age', hue='Survived', bins=30, kde=True, multiple="stack", palette='Set1')

plt.xlabel("Age")
plt.ylabel("Frequency")

plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.displot(df, x='Fare', hue='Survived', bins=30, kde=True, multiple="stack", palette='Set1')

plt.xlabel("Fare")
plt.ylabel("Frequency")

plt.show()

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr())
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_536\58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
#New Column

df['Family_size']=df['Parch']+df['SibSp']

# %%
df.sample(5)
# Out:
#      PassengerId Survived Pclass                               Name     Sex  \
# 44            45        1      3      Devaney, Miss. Margaret Delia  female
# 448          449        1      3     Baclini, Miss. Marie Catherine  female
# 627          628        1      1      Longley, Miss. Gretchen Fiske  female
# 684          685        0      2  Brown, Mr. Thomas William Solomon    male
# 216          217        1      3             Honkanen, Miss. Eliina  female
#
#      Age  SibSp  Parch            Ticket     Fare Embarked  Family_size
# 44    19      0      0            330958   7.8792        Q            0
# 448    5      2      1              2666  19.2583        C            3
# 627   21      0      0             13502  77.9583        S            0
# 684   60      1      1             29750  39.0000        S            2
# 216   27      0      0  STON/O2. 3101283   7.9250        S            0

# %%
def family_type(number):
    if number==0:
        return "Alone"
    elif number>0 and number<=4:
        return "Medium"
    else:
        return "Large"

# %%
df['Family_type']=df['Family_size'].apply(family_type)

# %%
df.sample(5)
# Out:
#      PassengerId Survived Pclass                                        Name  \
# 856          857        1      1  Wick, Mrs. George Dennick (Mary Hitchcock)
# 7              8        0      3              Palsson, Master. Gosta Leonard
# 235          236        0      3                Harknett, Miss. Alice Phoebe
# 890          891        0      3                         Dooley, Mr. Patrick
# 123          124        1      2                         Webber, Miss. Susan
#
#         Sex  Age  SibSp  Parch      Ticket      Fare Embarked  Family_size  \
# 856  female   45      1      1       36928  164.8667        S            2
# 7      male    2      3      1      349909   21.0750        S            4
# 235  female   29      0      0  W./C. 6609    7.5500        S            0
# 890    male   32      0      0      370376    7.7500        Q            0
# 123  female   32      0      0       27267   13.0000        S            0
#
#     Family_type
# 856      Medium
# 7        Medium
# ...

# %%
df.drop(columns=['SibSp','Parch','Family_size'], inplace =True)

# %%
df.sample(5)
# Out:
#      PassengerId Survived Pclass                            Name     Sex  Age  \
# 883          884        0      2   Banfield, Mr. Frederick James    male   28
# 404          405        0      3         Oreskovic, Miss. Marija  female   20
# 131          132        0      3  Coelho, Mr. Domingos Fernandeo    male   20
# 703          704        0      3           Gallagher, Mr. Martin    male   25
# 71            72        0      3      Goodwin, Miss. Lillian Amy  female   16
#
#                  Ticket     Fare Embarked Family_type
# 883    C.A./SOTON 34068  10.5000        S       Alone
# 404              315096   8.6625        S       Alone
# 131  SOTON/O.Q. 3101307   7.0500        S       Alone
# 703               36864   7.7417        Q       Alone
# 71              CA 2144  46.9000        S       Large

# %%
pd.crosstab(df['Family_type'],df['Survived']).apply(lambda r:round((r/r.sum())*100,1), axis=1)
# Out:
# Survived        0     1
# Family_type
# Alone        69.6  30.4
# Large        85.1  14.9
# Medium       44.0  56.0

# %% [markdown]
# Final Conclusion:
#     1. Chance of female survival is higher than male survival.
#     2. Travelling in P class 3 is deadliest.
#     3. Somehow, people going to Cherbourg suvived more.
#     4. People in age range of 20 to 40 had a higher chance of not surviving.
#     5. People travelling with smaller families had a higher chance of surviving the accident in comparison to people with large families and travelling alone.
